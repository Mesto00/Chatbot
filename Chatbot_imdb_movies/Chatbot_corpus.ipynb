# %%
import pandas as pd

# %%
data = pd.read_csv("IMDb_movies.csv",sep=',')
# Out:
# C:\Users\Salah\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
#   language                             director  ...  \
# 0     None                      Alexander Black  ...
# 1     None                         Charles Tait  ...
# 2      NaN                            Urban Gad  ...
# 3  English                   Charles L. Gaskill  ...
# 4  Italian  Francesco Bertolini, Adolfo Padovan  ...
#
#                                               actors  \
# 0  Blanche Bayliss, William Courtenay, Chauncey D...
# 1  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 2  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 3  Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 4  Salvatore Papa, Arturo Pirovano, Giuseppe de L...
#
#                                          description avg_vote votes   budget  \
# 0  The adventures of a female reporter in the 1890s.      5.9   154      NaN
# 1  True story of notorious Australian outlaw Ned ...      6.1   589   $ 2250
# 2  Two men of high rank are both wooing the beaut...      5.8   188      NaN
# 3  The fabled queen of Egypt's affair with Roman ...      5.2   446  $ 45000
# 4  Loosely adapted from Dante's Divine Comedy and...      7.0  2237      NaN
#
#    usa_gross_income worlwide_gross_income metascore reviews_from_users  \
# 0               NaN                   NaN       NaN                1.0
# 1               NaN                   NaN       NaN                7.0
# 2               NaN                   NaN       NaN                5.0
# 3               NaN                   NaN       NaN               25.0
# 4               NaN                   NaN       NaN               31.0
#
#    reviews_from_critics
# 0                   2.0
# 1                   7.0
# 2                   2.0
# 3                   3.0
# 4                  14.0
#
# [5 rows x 22 columns]

# %%
data = data.drop(['usa_gross_income', 'worlwide_gross_income',"metascore" ], axis=1)

# %%
columns = data.columns

# %%
columns
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'reviews_from_users', 'reviews_from_critics'],
#       dtype='object')

# %%
data = data.rename(columns={"imdb_title_id":"imdb title id", "original_title":"original title", "date_published":"date",
                            "production_company":"producer","avg_vote":"average of votes", "votes":"number of votes",
                            "reviews_from_users":"number of reviews from users","reviews_from_critics":"number of reviews from critics"})

# %%
columns = data.columns
columns
# Out:
# Index(['imdb title id', 'title', 'original title', 'year', 'date', 'genre',
#        'duration', 'country', 'language', 'director', 'writer', 'producer',
#        'actors', 'description', 'average of votes', 'number of votes',
#        'budget', 'number of reviews from users',
#        'number of reviews from critics'],
#       dtype='object')

# %%
data.shape
# Out:
# (85855, 19)

# %%
data = data.sort_values(by=['average of votes', 'number of votes'], ascending=False)

# %%
data.iloc[:5000,:]
# Out:
#       imdb title id                              title  \
# 83275     tt7822474                    Suvarna Sundari
# 84995     tt9008642                        Notuku Potu
# 56032    tt12492650                                 Ek
# 54217    tt11207902  Lejos de Casa pelicula Venezolana
# 55310    tt11976170                             Jeeudo
# ...             ...                                ...
# 7525      tt0045659                       Mare crudele
# 22291     tt0090203         In viaggio verso Bountiful
# 4208      tt0034946              Delitti senza castigo
# 12279     tt0059358                 Qualcuno da odiare
# 16568     tt0071585   Gruppo di famiglia in un interno
#
#                           original title  year        date  \
# 83275                    Suvarna Sundari  2019  2019-05-31
# 84995                        Notuku Potu  2017  2017-03-24
# 56032                                 Ek  2019  2019-06-14
# 54217  Lejos de Casa pelicula Venezolana  2020  2020-03-19
# 55310                             Jeeudo  2020  2020-02-27
# ...                                  ...   ...         ...
# 7525                       The Cruel Sea  1953  1953-10-23
# 22291              The Trip to Bountiful  1985  1986-01-24
# 4208                           Kings Row  1942  1948-10-28
# 12279                           King Rat  1965  1965-10-27
# 16568   Gruppo di famiglia in un interno  1974  1975-03-19
#
#                          genre  duration        country  \
# 83275         Action, Thriller       120          India
# 84995          Horror, Mystery       121          India
# 56032            Action, Drama       129          India
# 54217           Drama, History        87      Venezuela
# 55310           Drama, Romance       150          India
# ...                        ...       ...            ...
# 7525                Drama, War       126             UK
# 22291                    Drama       108            USA
# 4208   Drama, Mystery, Romance       127            USA
# 12279               Drama, War       134            USA
# 16568           Drama, Romance       126  Italy, France
#
#                        language          director  \
# 83275           Telugu, Kannada         Msn Surya
# 84995                    Telugu      Basheed S.K.
# 56032                    Telugu     Sampath Rudra
# 54217                   Spanish    Abner Official
# 55310           English, Nepali     Aalmist Subba
# ...                         ...               ...
# 7525                    English     Charles Frend
# 22291                   English   Peter Masterson
# 4208            English, French          Sam Wood
# 12279  English, Malay, Japanese      Bryan Forbes
# 16568          Italian, English  Luchino Visconti
#
#                                     writer                 producer  \
# 83275                                  NaN          S Team Pictures
# 84995                                  NaN                SBK Films
# 56032                        Harik Krishna           K World Movies
# 54217         Dariana Jozh, Abner Official                      NaN
# 55310        Aalmist Subba, Chanchal Thapa      Aalmist Productions
# ...                                    ...                      ...
# 7525       Nicholas Monsarrat, Eric Ambler           Ealing Studios
# 22291           Horton Foote, Horton Foote  Bountiful Film Partners
# 4208       Casey Robinson, Henry Bellamann             Warner Bros.
# 12279          James Clavell, Bryan Forbes                Coleytown
# 16568  Enrico Medioli, Suso Cecchi D'Amico             Rusconi Film
#
#                                                   actors  \
# 83275  Shamna Kasim, Sakshi Chaudhary, Jaya Prada, Av...
# 84995          Mumait Khan, Manisha Koirala, Arjun Sarja
# 56032  Bishnu Adhikari, Himanshi Khurana, Aparna Shar...
# 54217  Angibell, Gabriel Buitrago, Darwing, Dariana J...
# 55310  Prashant Baraili, Davina, Pranisha Gahatraj, P...
# ...                                                  ...
# 7525   Jack Hawkins, Donald Sinden, John Stratton, De...
# 22291  Geraldine Page, John Heard, Carlin Glynn, Rich...
# 4208   Ann Sheridan, Robert Cummings, Ronald Reagan, ...
# 12279  George Segal, Tom Courtenay, James Fox, Patric...
# 16568  Burt Lancaster, Helmut Berger, Silvana Mangano...
#
#                                              description  average of votes  \
# 83275  The movie revolves around an idol, Suvarna Sun...               9.9
# 84995  Notuku Potu is a crime story laced with elemen...               9.8
# 56032  EK is a love story set in the context of ever ...               9.8
# 54217  Samuel, a young Venezuelan, emigrates from his...               9.8
# 55310  "A TALE OF LOVE, MYTH, AND FATE" "JEEUDO" (mea...               9.8
# ...                                                  ...               ...
# 7525   The World War II adventures of a British convo...               7.5
# 22291  In 1940s Texas, an elderly woman is determined...               7.5
# 4208   The dark side and hypocrisy of provincial Amer...               7.5
# 12279  Fast-talking wheeler-dealer Corporal King is s...               7.5
# 16568  A reclusive, retired professor is faced with c...               7.5
#
#        number of votes        budget  number of reviews from users  \
# 83275              896           NaN                           NaN
# 84995              926           NaN                           2.0
# 56032              527  INR 20000000                           NaN
# 54217              133        $ 5000                           NaN
# 55310              130   INR 4700000                         114.0
# ...                ...           ...                           ...
# 7525              3965           NaN                          65.0
# 22291             3956           NaN                          72.0
# 4208              3940           NaN                          72.0
# 12279             3929           NaN                          49.0
# 16568             3917           NaN                          16.0
#
#        number of reviews from critics
# 83275                             2.0
# 84995                             1.0
# 56032                             NaN
# 54217                             NaN
# 55310                             NaN
# ...                               ...
# 7525                             27.0
# 22291                            17.0
# 4208                             19.0
# 12279                            16.0
# 16568                            46.0
#
# [5000 rows x 19 columns]

# %%
data.iloc[5,:]
# Out:
# imdb title id                                                            tt12747588
# title                                                                     Meka Suri
# original title                                                            Meka Suri
# year                                                                           2020
# date                                                                     2020-07-31
# genre                                                               Crime, Thriller
# duration                                                                         86
# country                                                                       India
# language                                                                     Telugu
# director                                                           Trinadh Velisila
# writer                                                                          NaN
# producer                                                        Simba Entertainment
# actors                            Abhinay, Naresh Byreddy, Sharat Kumar, Sravan,...
# description                       The story revolves around Meka Suri, a butcher...
# average of votes                                                                9.7
# number of votes                                                                1126
# budget                                                                          NaN
# number of reviews from users                                                  502.0
# number of reviews from critics                                                  NaN
# Name: 56329, dtype: object

# %%
mov = {"intents": [
        {"tag": "greeting",
         "patterns": ["Hi", "Hello", "Good morning", "Good evening", "Hey"],
         "responses": ["Hello", "Good to see you", "Hi"],
         "context": [""]
        },
        {"tag": "How are you",
         "patterns": ["How are you?", "How’s it going?", "How’s everything?", "How are things", "What's up", "What’s been going on"],
         "responses": ["I'm fine thank you", "Fine, what about you?", "Good and you?"],
         "context": [""]
        },
        {"tag": "goodbye",
         "patterns": ["See you", "See ya", "Bye", "See you later", "Goodbye", "Nice chatting to you, bye", "Till next time"],
         "responses": ["See you!", "Have a nice day", "Bye! Come back again soon."],
         "context": [""]
        },
        {"tag": "thanks",
         "patterns": ["Thanks", "Thank you", "That's helpful", "Awesome, thanks", "Thanks for helping me"],
         "responses": ["Happy to help!", "Any time!", "My pleasure"],
         "context": [""]
        },
        {"tag": "noanswer",
         "patterns": [],
         "responses": ["Sorry, can't understand you", "Please give me more info", "Not sure I understand"],
         "context": [""]
        },
        {"tag": "service",
         "patterns": ["What can you do?", "What can you provide?", "What's your role?", "What service do you provide?", "What type of information do you give?"],
         "responses": ["I can provide you with information about 85855 movies", "I can give you information about 85855 movies"],
         "context": [""]
        },
        {"tag": "insluts",
         "patterns": ["Fuck you", "Fuck off", "Are you dumb?", "Are you stupid?", "Dumb bot", "Stupid bot"],
         "responses": ["I won't reply to that", "Be polite please", "Watch your language" ,"What???????????"],
         "context": [""]
        }
]}
mov
# Out:
# {'intents': [{'tag': 'greeting',
#    'patterns': ['Hi', 'Hello', 'Good morning', 'Good evening', 'Hey'],
#    'responses': ['Hello', 'Good to see you', 'Hi'],
#    'context': ['']},
#   {'tag': 'How are you',
#    'patterns': ['How are you?',
#     'How’s it going?',
#     'How’s everything?',
#     'How are things',
#     "What's up",
#     'What’s been going on'],
#    'responses': ["I'm fine thank you",
#     'Fine, what about you?',
#     'Good and you?'],
#    'context': ['']},
#   {'tag': 'goodbye',
#    'patterns': ['See you',
#     'See ya',
#     'Bye',
#     'See you later',
#     'Goodbye',
#     'Nice chatting to you, bye',
#     'Till next time'],
#    'responses': ['See you!', 'Have a nice day', 'Bye! Come back again soon.'],
#    'context': ['']},
#   {'tag': 'thanks',
#    'patterns': ['Thanks',
#     'Thank you',
#     "That's helpful",
#     'Awesome, thanks',
#     'Thanks for helping me'],
#    'responses': ['Happy to help!', 'Any time!', 'My pleasure'],
#    'context': ['']},
#   {'tag': 'noanswer',
#    'patterns': [],
#    'responses': ["Sorry, can't understand you",
#     'Please give me more info',
#     'Not sure I understand'],
#    'context': ['']},
#   {'tag': 'service',
#    'patterns': ['What can you do?',
#     'What can you provide?',
#     "What's your role?",
#     'What service do you provide?',
#     'What type of information do you give?'],
#    'responses': ['I can provide you with information about 85855 movies',
#     'I can give you information about 85855 movies'],
#    'context': ['']},
#   {'tag': 'insluts',
#    'patterns': ['Fuck you',
#     'Fuck off',
#     'Are you dumb?',
#     'Are you stupid?',
#     'Dumb bot',
#     'Stupid bot'],
#    'responses': ["I won't reply to that",
#     'Be polite please',
#     'Watch your language',
#     'What???????????'],
#    'context': ['']}]}

# %%
columns
# Out:
# Index(['imdb title id', 'title', 'original title', 'year', 'date', 'genre',
#        'duration', 'country', 'language', 'director', 'writer', 'producer',
#        'actors', 'description', 'average of votes', 'number of votes',
#        'budget', 'number of reviews from users',
#        'number of reviews from critics'],
#       dtype='object')

# %%
data.shape[0]
# Out:
# 85855

# %%
for i in range(5000):
    for j in range(1,len(columns)):
        if columns[j]=="writer" or columns[j]=="producer" or columns[j]=="director":
            mov["intents"] += [{"tag": str(data.iloc[i,:][1] +" "+ columns[j]),
                            "patterns" : [columns[j]+" of "+data.iloc[i,:][1],"Who is the "+columns[j]+" of "+data.iloc[i,:][1], columns[j]+" of "+data.iloc[i,:][1]+"?"],
                            "responses" : [str(data.iloc[i,:][j])],
                            "context" : [""]
                            }]
        elif columns[j]=="actors":
            mov["intents"] += [{"tag": str(data.iloc[i,:][1] +" "+ columns[j]),
                            "patterns" : [columns[j]+" of "+data.iloc[i,:][1],"Who are the principle "+columns[j]+" of "+data.iloc[i,:][1] , "Who are the "+columns[j]+" of "+data.iloc[i,:][1],"Who are the main "+columns[j]+" of "+data.iloc[i,:][1] , columns[j]+" of "+data.iloc[i,:][1]+"?"],
                            "responses" : [str(data.iloc[i,:][j])],
                            "context" : [""]
                            }]
        else:
            mov["intents"] += [{"tag": str(data.iloc[i,:][1] +" "+ columns[j]),
                            "patterns" : [columns[j]+" of "+data.iloc[i,:][1], "What is the "+columns[j]+" of "+data.iloc[i,:][1], columns[j]+" of "+data.iloc[i,:][1]+"?"],
                            "responses" : [str(data.iloc[i,:][j])],
                            "context" : [""]
                            }]
mov
# Out:
# {'intents': [{'tag': 'greeting',
#    'patterns': ['Hi', 'Hello', 'Good morning', 'Good evening', 'Hey'],
#    'responses': ['Hello', 'Good to see you', 'Hi'],
#    'context': ['']},
#   {'tag': 'How are you',
#    'patterns': ['How are you?',
#     'How’s it going?',
#     'How’s everything?',
#     'How are things',
#     "What's up",
#     'What’s been going on'],
#    'responses': ["I'm fine thank you",
#     'Fine, what about you?',
#     'Good and you?'],
#    'context': ['']},
#   {'tag': 'goodbye',
#    'patterns': ['See you',
#     'See ya',
#     'Bye',
#     'See you later',
#     'Goodbye',
#     'Nice chatting to you, bye',
#     'Till next time'],
#    'responses': ['See you!', 'Have a nice day', 'Bye! Come back again soon.'],
#    'context': ['']},
#   {'tag': 'thanks',
#    'patterns': ['Thanks',
#     'Thank you',
#     "That's helpful",
#     'Awesome, thanks',
#     'Thanks for helping me'],
#    'responses': ['Happy to help!', 'Any time!', 'My pleasure'],
#    'context': ['']},
#   {'tag': 'noanswer',
#    'patterns': [],
#    'responses': ["Sorry, can't understand you",
#     'Please give me more info',
#     'Not sure I understand'],
#    'context': ['']},
#   {'tag': 'service',
#    'patterns': ['What can you do?',
#     'What can you provide?',
#     "What's your role?",
#     'What service do you provide?',
#     'What type of information do you give?'],
#    'responses': ['I can provide you with information about 85855 movies',
#     'I can give you information about 85855 movies'],
#    'context': ['']},
#   {'tag': 'insluts',
#    'patterns': ['Fuck you',
#     'Fuck off',
#     'Are you dumb?',
#     'Are you stupid?',
#     'Dumb bot',
#     'Stupid bot'],
#    'responses': ["I won't reply to that",
#     'Be polite please',
#     'Watch your language',
#     'What???????????'],
#    'context': ['']},
#   {'tag': 'Suvarna Sundari title',
#    'patterns': ['title of Suvarna Sundari',
#     'What is the title of Suvarna Sundari',
#     'title of Suvarna Sundari?'],
#    'responses': ['Suvarna Sundari'],
#    'context': ['']},
#   {'tag': 'Suvarna Sundari original title',
#    'patterns': ['original title of Suvarna Sundari',
#     'What is the original title of Suvarna Sundari',
#     'original title of Suvarna Sundari?'],
#    'responses': ['Suvarna Sundari'],
#    'context': ['']},
#   {'tag': 'Suvarna Sundari year',
#    'patterns': ['year of Suvarna Sundari',
#     'What is the year of Suvarna Sundari',
#     'year of Suvarna Sundari?'],
#    'responses': ['2019'],
#    'context': ['']},
#   {'tag': 'Suvarna Sundari date',
#    'patterns': ['date of Suvarna Sundari',
#     'What is the date of Suvarna Sundari',
#     'date of Suvarna Sundari?'],
#    'responses': ['2019-05-31'],
#    'context': ['']},
#   {'tag': 'Suvarna Sundari genre',
#    'patterns': ['genre of Suvarna Sundari',
#     'What is the genre of Suvarna Sundari',
#     'genre of Suvarna Sundari?'],
#    'responses': ['Action, Thriller'],
#    'context': ['']},
#   {'tag': 'Suvarna Sundari duration',
#    'patterns': ['duration of Suvarna Sundari',
#     'What is the duration of Suvarna Sundari',
#     'duration of Suvarna Sundari?'],
#    'responses': ['120'],
#    'context': ['']},
#   {'tag': 'Suvarna Sundari country',
#    'patterns': ['country of Suvarna Sundari',
#     'What is the country of Suvarna Sundari',
#     'country of Suvarna Sundari?'],
#    'responses': ['India'],
#    'context': ['']},
#   {'tag': 'Suvarna Sundari language',
#    'patterns': ['language of Suvarna Sundari',
#     'What is the language of Suvarna Sundari',
#     'language of Suvarna Sundari?'],
#    'responses': ['Telugu, Kannada'],
#    'context': ['']},
#   {'tag': 'Suvarna Sundari director',
#    'patterns': ['director of Suvarna Sundari',
#     'Who is the director of Suvarna Sundari',
#     'director of Suvarna Sundari?'],
#    'responses': ['Msn Surya'],
#    'context': ['']},
#   {'tag': 'Suvarna Sundari writer',
#    'patterns': ['writer of Suvarna Sundari',
#     'Who is the writer of Suvarna Sundari',
#     'writer of Suvarna Sundari?'],
#    'responses': ['nan'],
#    'context': ['']},
#   {'tag': 'Suvarna Sundari producer',
#    'patterns': ['producer of Suvarna Sundari',
#     'Who is the producer of Suvarna Sundari',
#     'producer of Suvarna Sundari?'],
#    'responses': ['S Team Pictures'],
#    'context': ['']},
#   {'tag': 'Suvarna Sundari actors',
#    'patterns': ['actors of Suvarna Sundari',
#     'Who are the principle actors of Suvarna Sundari',
#     'Who are the actors of Suvarna Sundari',
#     'Who are the main actors of Suvarna Sundari',
#     'actors of Suvarna Sundari?'],
#    'responses': ['Shamna Kasim, Sakshi Chaudhary, Jaya Prada, Avantika Vandanapu, Avinash, Indra, Srinivasa Rao Kota, Sai Kumar, Nagineedu, Sathya Prakash, Raam'],
#    'context': ['']},
#   {'tag': 'Suvarna Sundari description',
#    'patterns': ['description of Suvarna Sundari',
#     'What is the description of Suvarna Sundari',
#     'description of Suvarna Sundari?'],
#    'responses': ['The movie revolves around an idol, Suvarna Sundari and the effects of it. The idol, also known as Trinetri, dates back to 15th century. Whoever possesses the idol, becomes a victim of ...'],
#    'context': ['']},
#   {'tag': 'Suvarna Sundari average of votes',
#    'patterns': ['average of votes of Suvarna Sundari',
#     'What is the average of votes of Suvarna Sundari',
#     'average of votes of Suvarna Sundari?'],
#    'responses': ['9.9'],
#    'context': ['']},
#   {'tag': 'Suvarna Sundari number of votes',
#    'patterns': ['number of votes of Suvarna Sundari',
#     'What is the number of votes of Suvarna Sundari',
#     'number of votes of Suvarna Sundari?'],
#    'responses': ['896'],
#    'context': ['']},
#   {'tag': 'Suvarna Sundari budget',
#    'patterns': ['budget of Suvarna Sundari',
#     'What is the budget of Suvarna Sundari',
#     'budget of Suvarna Sundari?'],
#    'responses': ['nan'],
#    'context': ['']},
#   {'tag': 'Suvarna Sundari number of reviews from users',
#    'patterns': ['number of reviews from users of Suvarna Sundari',
#     'What is the number of reviews from users of Suvarna Sundari',
#     'number of reviews from users of Suvarna Sundari?'],
#    'responses': ['nan'],
#    'context': ['']},
#   {'tag': 'Suvarna Sundari number of reviews from critics',
#    'patterns': ['number of reviews from critics of Suvarna Sundari',
#     'What is the number of reviews from critics of Suvarna Sundari',
#     'number of reviews from critics of Suvarna Sundari?'],
#    'responses': ['2.0'],
#    'context': ['']},
#   {'tag': 'Notuku Potu title',
#    'patterns': ['title of Notuku Potu',
#     'What is the title of Notuku Potu',
#     'title of Notuku Potu?'],
#    'responses': ['Notuku Potu'],
#    'context': ['']},
#   {'tag': 'Notuku Potu original title',
#    'patterns': ['original title of Notuku Potu',
#     'What is the original title of Notuku Potu',
#     'original title of Notuku Potu?'],
#    'responses': ['Notuku Potu'],
#    'context': ['']},
#   {'tag': 'Notuku Potu year',
#    'patterns': ['year of Notuku Potu',
#     'What is the year of Notuku Potu',
#     'year of Notuku Potu?'],
#    'responses': ['2017'],
#    'context': ['']},
#   {'tag': 'Notuku Potu date',
#    'patterns': ['date of Notuku Potu',
#     'What is the date of Notuku Potu',
#     'date of Notuku Potu?'],
#    'responses': ['2017-03-24'],
#    'context': ['']},
#   {'tag': 'Notuku Potu genre',
#    'patterns': ['genre of Notuku Potu',
#     'What is the genre of Notuku Potu',
#     'genre of Notuku Potu?'],
#    'responses': ['Horror, Mystery'],
#    'context': ['']},
#   {'tag': 'Notuku Potu duration',
#    'patterns': ['duration of Notuku Potu',
#     'What is the duration of Notuku Potu',
#     'duration of Notuku Potu?'],
#    'responses': ['121'],
#    'context': ['']},
#   {'tag': 'Notuku Potu country',
#    'patterns': ['country of Notuku Potu',
#     'What is the country of Notuku Potu',
#     'country of Notuku Potu?'],
#    'responses': ['India'],
#    'context': ['']},
#   {'tag': 'Notuku Potu language',
#    'patterns': ['language of Notuku Potu',
#     'What is the language of Notuku Potu',
#     'language of Notuku Potu?'],
#    'responses': ['Telugu'],
#    'context': ['']},
#   {'tag': 'Notuku Potu director',
#    'patterns': ['director of Notuku Potu',
#     'Who is the director of Notuku Potu',
#     'director of Notuku Potu?'],
#    'responses': ['Basheed S.K.'],
#    'context': ['']},
#   {'tag': 'Notuku Potu writer',
#    'patterns': ['writer of Notuku Potu',
#     'Who is the writer of Notuku Potu',
#     'writer of Notuku Potu?'],
#    'responses': ['nan'],
#    'context': ['']},
#   {'tag': 'Notuku Potu producer',
#    'patterns': ['producer of Notuku Potu',
#     'Who is the producer of Notuku Potu',
#     'producer of Notuku Potu?'],
#    'responses': ['SBK Films'],
#    'context': ['']},
#   {'tag': 'Notuku Potu actors',
#    'patterns': ['actors of Notuku Potu',
#     'Who are the principle actors of Notuku Potu',
#     'Who are the actors of Notuku Potu',
#     'Who are the main actors of Notuku Potu',
#     'actors of Notuku Potu?'],
#    'responses': ['Mumait Khan, Manisha Koirala, Arjun Sarja'],
#    'context': ['']},
#   {'tag': 'Notuku Potu description',
#    'patterns': ['description of Notuku Potu',
#     'What is the description of Notuku Potu',
#     'description of Notuku Potu?'],
#    'responses': ['Notuku Potu is a crime story laced with elements of horror and thrill. The story is about a man who, after the death of a woman, is pulled into a world of mystery and conspiracy.'],
#    'context': ['']},
#   {'tag': 'Notuku Potu average of votes',
#    'patterns': ['average of votes of Notuku Potu',
#     'What is the average of votes of Notuku Potu',
#     'average of votes of Notuku Potu?'],
#    'responses': ['9.8'],
#    'context': ['']},
#   {'tag': 'Notuku Potu number of votes',
#    'patterns': ['number of votes of Notuku Potu',
#     'What is the number of votes of Notuku Potu',
#     'number of votes of Notuku Potu?'],
#    'responses': ['926'],
#    'context': ['']},
#   {'tag': 'Notuku Potu budget',
#    'patterns': ['budget of Notuku Potu',
#     'What is the budget of Notuku Potu',
#     'budget of Notuku Potu?'],
#    'responses': ['nan'],
#    'context': ['']},
#   {'tag': 'Notuku Potu number of reviews from users',
#    'patterns': ['number of reviews from users of Notuku Potu',
#     'What is the number of reviews from users of Notuku Potu',
#     'number of reviews from users of Notuku Potu?'],
#    'responses': ['2.0'],
#    'context': ['']},
#   {'tag': 'Notuku Potu number of reviews from critics',
#    'patterns': ['number of reviews from critics of Notuku Potu',
#     'What is the number of reviews from critics of Notuku Potu',
#     'number of reviews from critics of Notuku Potu?'],
#    'responses': ['1.0'],
#    'context': ['']},
#   {'tag': 'Ek title',
#    'patterns': ['title of Ek', 'What is the title of Ek', 'title of Ek?'],
#    'responses': ['Ek'],
#    'context': ['']},
#   {'tag': 'Ek original title',
#    'patterns': ['original title of Ek',
#     'What is the original title of Ek',
#     'original title of Ek?'],
#    'responses': ['Ek'],
#    'context': ['']},
#   {'tag': 'Ek year',
#    'patterns': ['year of Ek', 'What is the year of Ek', 'year of Ek?'],
#    'responses': ['2019'],
#    'context': ['']},
#   {'tag': 'Ek date',
#    'patterns': ['date of Ek', 'What is the date of Ek', 'date of Ek?'],
#    'responses': ['2019-06-14'],
#    'context': ['']},
#   {'tag': 'Ek genre',
#    'patterns': ['genre of Ek', 'What is the genre of Ek', 'genre of Ek?'],
#    'responses': ['Action, Drama'],
#    'context': ['']},
#   {'tag': 'Ek duration',
#    'patterns': ['duration of Ek',
#     'What is the duration of Ek',
#     'duration of Ek?'],
#    'responses': ['129'],
#    'context': ['']},
#   {'tag': 'Ek country',
#    'patterns': ['country of Ek',
#     'What is the country of Ek',
#     'country of Ek?'],
#    'responses': ['India'],
#    'context': ['']},
#   {'tag': 'Ek language',
#    'patterns': ['language of Ek',
#     'What is the language of Ek',
#     'language of Ek?'],
#    'responses': ['Telugu'],
#    'context': ['']},
#   {'tag': 'Ek director',
#    'patterns': ['director of Ek',
#     'Who is the director of Ek',
#     'director of Ek?'],
#    'responses': ['Sampath Rudra'],
#    'context': ['']},
#   {'tag': 'Ek writer',
#    'patterns': ['writer of Ek', 'Who is the writer of Ek', 'writer of Ek?'],
#    'responses': ['Harik Krishna'],
#    'context': ['']},
#   {'tag': 'Ek producer',
#    'patterns': ['producer of Ek',
#     'Who is the producer of Ek',
#     'producer of Ek?'],
#    'responses': ['K World Movies'],
#    'context': ['']},
#   {'tag': 'Ek actors',
#    'patterns': ['actors of Ek',
#     'Who are the principle actors of Ek',
#     'Who are the actors of Ek',
#     'Who are the main actors of Ek',
#     'actors of Ek?'],
#    'responses': ['Bishnu Adhikari, Himanshi Khurana, Aparna Sharma, Prudhviraj, Banerjee, Suman, Sravan'],
#    'context': ['']},
#   {'tag': 'Ek description',
#    'patterns': ['description of Ek',
#     'What is the description of Ek',
#     'description of Ek?'],
#    'responses': ["EK is a love story set in the context of ever growing threat of suicide bombings in the country and across the world. It's a stylishly shot emotional action thriller with realistic ..."],
#    'context': ['']},
#   {'tag': 'Ek average of votes',
#    'patterns': ['average of votes of Ek',
#     'What is the average of votes of Ek',
#     'average of votes of Ek?'],
#    'responses': ['9.8'],
#    'context': ['']},
#   {'tag': 'Ek number of votes',
#    'patterns': ['number of votes of Ek',
#     'What is the number of votes of Ek',
#     'number of votes of Ek?'],
#    'responses': ['527'],
#    'context': ['']},
#   {'tag': 'Ek budget',
#    'patterns': ['budget of Ek', 'What is the budget of Ek', 'budget of Ek?'],
#    'responses': ['INR 20000000'],
#    'context': ['']},
#   {'tag': 'Ek number of reviews from users',
#    'patterns': ['number of reviews from users of Ek',
#     'What is the number of reviews from users of Ek',
#     'number of reviews from users of Ek?'],
#    'responses': ['nan'],
#    'context': ['']},
#   {'tag': 'Ek number of reviews from critics',
#    'patterns': ['number of reviews from critics of Ek',
#     'What is the number of reviews from critics of Ek',
#     'number of reviews from critics of Ek?'],
#    'responses': ['nan'],
#    'context': ['']},
#   {'tag': 'Lejos de Casa pelicula Venezolana title',
#    'patterns': ['title of Lejos de Casa pelicula Venezolana',
#     'What is the title of Lejos de Casa pelicula Venezolana',
#     'title of Lejos de Casa pelicula Venezolana?'],
#    'responses': ['Lejos de Casa pelicula Venezolana'],
#    'context': ['']},
#   {'tag': 'Lejos de Casa pelicula Venezolana original title',
#    'patterns': ['original title of Lejos de Casa pelicula Venezolana',
#     'What is the original title of Lejos de Casa pelicula Venezolana',
#     'original title of Lejos de Casa pelicula Venezolana?'],
#    'responses': ['Lejos de Casa pelicula Venezolana'],
#    'context': ['']},
#   {'tag': 'Lejos de Casa pelicula Venezolana year',
#    'patterns': ['year of Lejos de Casa pelicula Venezolana',
#     'What is the year of Lejos de Casa pelicula Venezolana',
#     'year of Lejos de Casa pelicula Venezolana?'],
#    'responses': ['2020'],
#    'context': ['']},
#   {'tag': 'Lejos de Casa pelicula Venezolana date',
#    'patterns': ['date of Lejos de Casa pelicula Venezolana',
#     'What is the date of Lejos de Casa pelicula Venezolana',
#     'date of Lejos de Casa pelicula Venezolana?'],
#    'responses': ['2020-03-19'],
#    'context': ['']},
#   {'tag': 'Lejos de Casa pelicula Venezolana genre',
#    'patterns': ['genre of Lejos de Casa pelicula Venezolana',
#     'What is the genre of Lejos de Casa pelicula Venezolana',
#     'genre of Lejos de Casa pelicula Venezolana?'],
#    'responses': ['Drama, History'],
#    'context': ['']},
#   {'tag': 'Lejos de Casa pelicula Venezolana duration',
#    'patterns': ['duration of Lejos de Casa pelicula Venezolana',
#     'What is the duration of Lejos de Casa pelicula Venezolana',
#     'duration of Lejos de Casa pelicula Venezolana?'],
#    'responses': ['87'],
#    'context': ['']},
#   {'tag': 'Lejos de Casa pelicula Venezolana country',
#    'patterns': ['country of Lejos de Casa pelicula Venezolana',
#     'What is the country of Lejos de Casa pelicula Venezolana',
#     'country of Lejos de Casa pelicula Venezolana?'],
#    'responses': ['Venezuela'],
#    'context': ['']},
#   {'tag': 'Lejos de Casa pelicula Venezolana language',
#    'patterns': ['language of Lejos de Casa pelicula Venezolana',
#     'What is the language of Lejos de Casa pelicula Venezolana',
#     'language of Lejos de Casa pelicula Venezolana?'],
#    'responses': ['Spanish'],
#    'context': ['']},
#   {'tag': 'Lejos de Casa pelicula Venezolana director',
#    'patterns': ['director of Lejos de Casa pelicula Venezolana',
#     'Who is the director of Lejos de Casa pelicula Venezolana',
#     'director of Lejos de Casa pelicula Venezolana?'],
#    'responses': ['Abner Official'],
#    'context': ['']},
#   {'tag': 'Lejos de Casa pelicula Venezolana writer',
#    'patterns': ['writer of Lejos de Casa pelicula Venezolana',
#     'Who is the writer of Lejos de Casa pelicula Venezolana',
#     'writer of Lejos de Casa pelicula Venezolana?'],
#    'responses': ['Dariana Jozh, Abner Official'],
#    'context': ['']},
#   {'tag': 'Lejos de Casa pelicula Venezolana producer',
#    'patterns': ['producer of Lejos de Casa pelicula Venezolana',
#     'Who is the producer of Lejos de Casa pelicula Venezolana',
#     'producer of Lejos de Casa pelicula Venezolana?'],
#    'responses': ['nan'],
#    'context': ['']},
#   {'tag': 'Lejos de Casa pelicula Venezolana actors',
#    'patterns': ['actors of Lejos de Casa pelicula Venezolana',
#     'Who are the principle actors of Lejos de Casa pelicula Venezolana',
#     'Who are the actors of Lejos de Casa pelicula Venezolana',
#     'Who are the main actors of Lejos de Casa pelicula Venezolana',
#     'actors of Lejos de Casa pelicula Venezolana?'],
#    'responses': ['Angibell, Gabriel Buitrago, Darwing, Dariana Jozh, Marko, Abner Official, Yroski'],
#    'context': ['']},
#   {'tag': 'Lejos de Casa pelicula Venezolana description',
#    'patterns': ['description of Lejos de Casa pelicula Venezolana',
#     'What is the description of Lejos de Casa pelicula Venezolana',
#     'description of Lejos de Casa pelicula Venezolana?'],
#    'responses': ['Samuel, a young Venezuelan, emigrates from his country in search of a better life and to help his family, without knowing the difficult situations that he will face as an immigrant.'],
#    'context': ['']},
#   {'tag': 'Lejos de Casa pelicula Venezolana average of votes',
#    'patterns': ['average of votes of Lejos de Casa pelicula Venezolana',
#     'What is the average of votes of Lejos de Casa pelicula Venezolana',
#     'average of votes of Lejos de Casa pelicula Venezolana?'],
#    'responses': ['9.8'],
#    'context': ['']},
#   {'tag': 'Lejos de Casa pelicula Venezolana number of votes',
#    'patterns': ['number of votes of Lejos de Casa pelicula Venezolana',
#     'What is the number of votes of Lejos de Casa pelicula Venezolana',
#     'number of votes of Lejos de Casa pelicula Venezolana?'],
#    'responses': ['133'],
#    'context': ['']},
#   {'tag': 'Lejos de Casa pelicula Venezolana budget',
#    'patterns': ['budget of Lejos de Casa pelicula Venezolana',
#     'What is the budget of Lejos de Casa pelicula Venezolana',
#     'budget of Lejos de Casa pelicula Venezolana?'],
#    'responses': ['$ 5000'],
#    'context': ['']},
#   {'tag': 'Lejos de Casa pelicula Venezolana number of reviews from users',
#    'patterns': ['number of reviews from users of Lejos de Casa pelicula Venezolana',
#     'What is the number of reviews from users of Lejos de Casa pelicula Venezolana',
#     'number of reviews from users of Lejos de Casa pelicula Venezolana?'],
#    'responses': ['nan'],
#    'context': ['']},
#   {'tag': 'Lejos de Casa pelicula Venezolana number of reviews from critics',
#    'patterns': ['number of reviews from critics of Lejos de Casa pelicula Venezolana',
#     'What is the number of reviews from critics of Lejos de Casa pelicula Venezolana',
#     'number of reviews from critics of Lejos de Casa pelicula Venezolana?'],
#    'responses': ['nan'],
#    'context': ['']},
#   {'tag': 'Jeeudo title',
#    'patterns': ['title of Jeeudo',
#     'What is the title of Jeeudo',
#     'title of Jeeudo?'],
#    'responses': ['Jeeudo'],
#    'context': ['']},
#   {'tag': 'Jeeudo original title',
#    'patterns': ['original title of Jeeudo',
#     'What is the original title of Jeeudo',
#     'original title of Jeeudo?'],
#    'responses': ['Jeeudo'],
#    'context': ['']},
#   {'tag': 'Jeeudo year',
#    'patterns': ['year of Jeeudo',
#     'What is the year of Jeeudo',
#     'year of Jeeudo?'],
#    'responses': ['2020'],
#    'context': ['']},
#   {'tag': 'Jeeudo date',
#    'patterns': ['date of Jeeudo',
#     'What is the date of Jeeudo',
#     'date of Jeeudo?'],
#    'responses': ['2020-02-27'],
#    'context': ['']},
#   {'tag': 'Jeeudo genre',
#    'patterns': ['genre of Jeeudo',
#     'What is the genre of Jeeudo',
#     'genre of Jeeudo?'],
#    'responses': ['Drama, Romance'],
#    'context': ['']},
#   {'tag': 'Jeeudo duration',
#    'patterns': ['duration of Jeeudo',
#     'What is the duration of Jeeudo',
#     'duration of Jeeudo?'],
#    'responses': ['150'],
#    'context': ['']},
#   {'tag': 'Jeeudo country',
#    'patterns': ['country of Jeeudo',
#     'What is the country of Jeeudo',
#     'country of Jeeudo?'],
#    'responses': ['India'],
#    'context': ['']},
#   {'tag': 'Jeeudo language',
#    'patterns': ['language of Jeeudo',
#     'What is the language of Jeeudo',
#     'language of Jeeudo?'],
#    'responses': ['English, Nepali'],
#    'context': ['']},
#   {'tag': 'Jeeudo director',
#    'patterns': ['director of Jeeudo',
#     'Who is the director of Jeeudo',
#     'director of Jeeudo?'],
#    'responses': ['Aalmist Subba'],
#    'context': ['']},
#   {'tag': 'Jeeudo writer',
#    'patterns': ['writer of Jeeudo',
#     'Who is the writer of Jeeudo',
#     'writer of Jeeudo?'],
#    'responses': ['Aalmist Subba, Chanchal Thapa'],
#    'context': ['']},
#   {'tag': 'Jeeudo producer',
#    'patterns': ['producer of Jeeudo',
#     'Who is the producer of Jeeudo',
#     'producer of Jeeudo?'],
#    'responses': ['Aalmist Productions'],
#    'context': ['']},
#   {'tag': 'Jeeudo actors',
#    'patterns': ['actors of Jeeudo',
#     'Who are the principle actors of Jeeudo',
#     'Who are the actors of Jeeudo',
#     'Who are the main actors of Jeeudo',
#     'actors of Jeeudo?'],
#    'responses': ['Prashant Baraili, Davina, Pranisha Gahatraj, Pujan Ghishing, Budhiman Rai, Shradha Sharma, Kesang Sir, Aalmist Subba, Birbal Subba, Priten Tamang, Koiling Lepcha Yue'],
#    'context': ['']},
#   {'tag': 'Jeeudo description',
#    'patterns': ['description of Jeeudo',
#     'What is the description of Jeeudo',
#     'description of Jeeudo?'],
#    'responses': ['"A TALE OF LOVE, MYTH, AND FATE" "JEEUDO" (meaning "Alive"), it\'s a tale of Love, Myth, and Fate. At its core, is an innocent story of love, friendship, and sacrifice of the three ...'],
#    'context': ['']},
#   {'tag': 'Jeeudo average of votes',
#    'patterns': ['average of votes of Jeeudo',
#     'What is the average of votes of Jeeudo',
#     'average of votes of Jeeudo?'],
#    'responses': ['9.8'],
#    'context': ['']},
#   {'tag': 'Jeeudo number of votes',
#    'patterns': ['number of votes of Jeeudo',
#     'What is the number of votes of Jeeudo',
#     'number of votes of Jeeudo?'],
#    'responses': ['130'],
#    'context': ['']},
#   {'tag': 'Jeeudo budget',
#    'patterns': ['budget of Jeeudo',
#     'What is the budget of Jeeudo',
#     'budget of Jeeudo?'],
#    'responses': ['INR 4700000'],
#    'context': ['']},
#   {'tag': 'Jeeudo number of reviews from users',
#    'patterns': ['number of reviews from users of Jeeudo',
#     'What is the number of reviews from users of Jeeudo',
#     'number of reviews from users of Jeeudo?'],
#    'responses': ['114.0'],
#    'context': ['']},
#   {'tag': 'Jeeudo number of reviews from critics',
#    'patterns': ['number of reviews from critics of Jeeudo',
#     'What is the number of reviews from critics of Jeeudo',
#     'number of reviews from critics of Jeeudo?'],
#    'responses': ['nan'],
#    'context': ['']},
#   {'tag': 'Meka Suri title',
#    'patterns': ['title of Meka Suri',
#     'What is the title of Meka Suri',
#     'title of Meka Suri?'],
#    'responses': ['Meka Suri'],
#    'context': ['']},
#   {'tag': 'Meka Suri original title',
#    'patterns': ['original title of Meka Suri',
#     'What is the original title of Meka Suri',
#     'original title of Meka Suri?'],
#    'responses': ['Meka Suri'],
#    'context': ['']},
#   {'tag': 'Meka Suri year',
#    'patterns': ['year of Meka Suri',
#     'What is the year of Meka Suri',
#     'year of Meka Suri?'],
#    'responses': ['2020'],
#    'context': ['']},
#   {'tag': 'Meka Suri date',
#    'patterns': ['date of Meka Suri',
#     'What is the date of Meka Suri',
#     'date of Meka Suri?'],
#    'responses': ['2020-07-31'],
#    'context': ['']},
#   {'tag': 'Meka Suri genre',
#    'patterns': ['genre of Meka Suri',
#     'What is the genre of Meka Suri',
#     'genre of Meka Suri?'],
#    'responses': ['Crime, Thriller'],
#    'context': ['']},
#   {'tag': 'Meka Suri duration',
#    'patterns': ['duration of Meka Suri',
#     'What is the duration of Meka Suri',
#     'duration of Meka Suri?'],
#    'responses': ['86'],
#    'context': ['']},
#   {'tag': 'Meka Suri country',
#    'patterns': ['country of Meka Suri',
#     'What is the country of Meka Suri',
#     'country of Meka Suri?'],
#    'responses': ['India'],
#    'context': ['']},
#   {'tag': 'Meka Suri language',
#    'patterns': ['language of Meka Suri',
#     'What is the language of Meka Suri',
#     'language of Meka Suri?'],
#    'responses': ['Telugu'],
#    'context': ['']},
#   {'tag': 'Meka Suri director',
#    'patterns': ['director of Meka Suri',
#     'Who is the director of Meka Suri',
#     'director of Meka Suri?'],
#    'responses': ['Trinadh Velisila'],
#    'context': ['']},
#   {'tag': 'Meka Suri writer',
#    'patterns': ['writer of Meka Suri',
#     'Who is the writer of Meka Suri',
#     'writer of Meka Suri?'],
#    'responses': ['nan'],
#    'context': ['']},
#   {'tag': 'Meka Suri producer',
#    'patterns': ['producer of Meka Suri',
#     'Who is the producer of Meka Suri',
#     'producer of Meka Suri?'],
#    'responses': ['Simba Entertainment'],
#    'context': ['']},
#   {'tag': 'Meka Suri actors',
#    'patterns': ['actors of Meka Suri',
#     'Who are the principle actors of Meka Suri',
#     'Who are the actors of Meka Suri',
#     'Who are the main actors of Meka Suri',
#     'actors of Meka Suri?'],
#    'responses': ['Abhinay, Naresh Byreddy, Sharat Kumar, Sravan, Sumaya Syed'],
#    'context': ['']},
#   {'tag': 'Meka Suri description',
#    'patterns': ['description of Meka Suri',
#     'What is the description of Meka Suri',
#     'description of Meka Suri?'],
#    'responses': ['The story revolves around Meka Suri, a butcher, who gets married to his love, Rani. However, when Rani gets brutally murdered by a group of people, Meka Suri decides to avenge her death with the help of Naxalites.'],
#    'context': ['']},
#   {'tag': 'Meka Suri average of votes',
#    'patterns': ['average of votes of Meka Suri',
#     'What is the average of votes of Meka Suri',
#     'average of votes of Meka Suri?'],
#    'responses': ['9.7'],
#    'context': ['']},
#   {'tag': 'Meka Suri number of votes',
#    'patterns': ['number of votes of Meka Suri',
#     'What is the number of votes of Meka Suri',
#     'number of votes of Meka Suri?'],
#    'responses': ['1126'],
#    'context': ['']},
#   {'tag': 'Meka Suri budget',
#    'patterns': ['budget of Meka Suri',
#     'What is the budget of Meka Suri',
#     'budget of Meka Suri?'],
#    'responses': ['nan'],
#    'context': ['']},
#   {'tag': 'Meka Suri number of reviews from users',
#    'patterns': ['number of reviews from users of Meka Suri',
#     'What is the number of reviews from users of Meka Suri',
#     'number of reviews from users of Meka Suri?'],
#    'responses': ['502.0'],
#    'context': ['']},
#   {'tag': 'Meka Suri number of reviews from critics',
#    'patterns': ['number of reviews from critics of Meka Suri',
#     'What is the number of reviews from critics of Meka Suri',
#     'number of reviews from critics of Meka Suri?'],
#    'responses': ['nan'],
#    'context': ['']},
#   {'tag': 'Hopeful Notes title',
#    'patterns': ['title of Hopeful Notes',
#     'What is the title of Hopeful Notes',
#     'title of Hopeful Notes?'],
#    'responses': ['Hopeful Notes'],
#    'context': ['']},
#   {'tag': 'Hopeful Notes original title',
#    'patterns': ['original title of Hopeful Notes',
#     'What is the original title of Hopeful Notes',
#     'original title of Hopeful Notes?'],
#    'responses': ['Hopeful Notes'],
#    'context': ['']},
#   {'tag': 'Hopeful Notes year',
#    'patterns': ['year of Hopeful Notes',
#     'What is the year of Hopeful Notes',
#     'year of Hopeful Notes?'],
#    'responses': ['2010'],
#    'context': ['']},
#   {'tag': 'Hopeful Notes date',
#    'patterns': ['date of Hopeful Notes',
#     'What is the date of Hopeful Notes',
#     'date of Hopeful Notes?'],
#    'responses': ['2010-12-15'],
#    'context': ['']},
#   {'tag': 'Hopeful Notes genre',
#    'patterns': ['genre of Hopeful Notes',
#     'What is the genre of Hopeful Notes',
#     'genre of Hopeful Notes?'],
#    'responses': ['Drama'],
#    'context': ['']},
#   {'tag': 'Hopeful Notes duration',
#    'patterns': ['duration of Hopeful Notes',
#     'What is the duration of Hopeful Notes',
#     'duration of Hopeful Notes?'],
#    'responses': ['94'],
#    'context': ['']},
#   {'tag': 'Hopeful Notes country',
#    'patterns': ['country of Hopeful Notes',
#     'What is the country of Hopeful Notes',
#     'country of Hopeful Notes?'],
#    'responses': ['USA'],
#    'context': ['']},
#   {'tag': 'Hopeful Notes language',
#    'patterns': ['language of Hopeful Notes',
#     'What is the language of Hopeful Notes',
#     'language of Hopeful Notes?'],
#    'responses': ['English'],
#    'context': ['']},
#   {'tag': 'Hopeful Notes director',
#    'patterns': ['director of Hopeful Notes',
#     'Who is the director of Hopeful Notes',
#     'director of Hopeful Notes?'],
#    'responses': ['Valerio Zanoli'],
#    'context': ['']},
#   {'tag': 'Hopeful Notes writer',
#    'patterns': ['writer of Hopeful Notes',
#     'Who is the writer of Hopeful Notes',
#     'writer of Hopeful Notes?'],
#    'responses': ['Valerio Zanoli'],
#    'context': ['']},
#   {'tag': 'Hopeful Notes producer',
#    'patterns': ['producer of Hopeful Notes',
#     'Who is the producer of Hopeful Notes',
#     'producer of Hopeful Notes?'],
#    'responses': ['High Concept'],
#    'context': ['']},
#   {'tag': 'Hopeful Notes actors',
#    'patterns': ['actors of Hopeful Notes',
#     'Who are the principle actors of Hopeful Notes',
#     'Who are the actors of Hopeful Notes',
#     'Who are the main actors of Hopeful Notes',
#     'actors of Hopeful Notes?'],
#    'responses': ['Walter Nudo, Colin Ross, Ian Poland, Laural Merlington, Sharon Hayes, Kimberly Harsch, Robert Gray, Grace Heemstra, Kaitlyn Squires, Nicholas Sarjeant, Abeni Wimbush, Rocky Rector, Dennis Janiske, Lori Silvey'],
#    'context': ['']},
#   {'tag': 'Hopeful Notes description',
#    'patterns': ['description of Hopeful Notes',
#     'What is the description of Hopeful Notes',
#     'description of Hopeful Notes?'],
#    'responses': ['A young violinist with leukemia brings hope and life into a desolate Russian hospital for children.'],
#    'context': ['']},
#   {'tag': 'Hopeful Notes average of votes',
#    'patterns': ['average of votes of Hopeful Notes',
#     'What is the average of votes of Hopeful Notes',
#     'average of votes of Hopeful Notes?'],
#    'responses': ['9.7'],
#    'context': ['']},
#   {'tag': 'Hopeful Notes number of votes',
#    'patterns': ['number of votes of Hopeful Notes',
#     'What is the number of votes of Hopeful Notes',
#     'number of votes of Hopeful Notes?'],
#    'responses': ['669'],
#    'context': ['']},
#   {'tag': 'Hopeful Notes budget',
#    'patterns': ['budget of Hopeful Notes',
#     'What is the budget of Hopeful Notes',
#     'budget of Hopeful Notes?'],
#    'responses': ['$ 1500000'],
#    'context': ['']},
#   {'tag': 'Hopeful Notes number of reviews from users',
#    'patterns': ['number of reviews from users of Hopeful Notes',
#     'What is the number of reviews from users of Hopeful Notes',
#     'number of reviews from users of Hopeful Notes?'],
#    'responses': ['2.0'],
#    'context': ['']},
#   {'tag': 'Hopeful Notes number of reviews from critics',
#    'patterns': ['number of reviews from critics of Hopeful Notes',
#     'What is the number of reviews from critics of Hopeful Notes',
#     'number of reviews from critics of Hopeful Notes?'],
#    'responses': ['2.0'],
#    'context': ['']},
#   {'tag': 'Vaarthakal Ithuvare title',
#    'patterns': ['title of Vaarthakal Ithuvare',
#     'What is the title of Vaarthakal Ithuvare',
#     'title of Vaarthakal Ithuvare?'],
#    'responses': ['Vaarthakal Ithuvare'],
#    'context': ['']},
#   {'tag': 'Vaarthakal Ithuvare original title',
#    'patterns': ['original title of Vaarthakal Ithuvare',
#     'What is the original title of Vaarthakal Ithuvare',
#     'original title of Vaarthakal Ithuvare?'],
#    'responses': ['Vaarthakal Ithuvare'],
#    'context': ['']},
#   {'tag': 'Vaarthakal Ithuvare year',
#    'patterns': ['year of Vaarthakal Ithuvare',
#     'What is the year of Vaarthakal Ithuvare',
#     'year of Vaarthakal Ithuvare?'],
#    'responses': ['2019'],
#    'context': ['']},
#   {'tag': 'Vaarthakal Ithuvare date',
#    'patterns': ['date of Vaarthakal Ithuvare',
#     'What is the date of Vaarthakal Ithuvare',
#     'date of Vaarthakal Ithuvare?'],
#    'responses': ['2019-11-22'],
#    'context': ['']},
#   {'tag': 'Vaarthakal Ithuvare genre',
#    'patterns': ['genre of Vaarthakal Ithuvare',
#     'What is the genre of Vaarthakal Ithuvare',
#     'genre of Vaarthakal Ithuvare?'],
#    'responses': ['Comedy'],
#    'context': ['']},
#   {'tag': 'Vaarthakal Ithuvare duration',
#    'patterns': ['duration of Vaarthakal Ithuvare',
#     'What is the duration of Vaarthakal Ithuvare',
#     'duration of Vaarthakal Ithuvare?'],
#    'responses': ['121'],
#    'context': ['']},
#   {'tag': 'Vaarthakal Ithuvare country',
#    'patterns': ['country of Vaarthakal Ithuvare',
#     'What is the country of Vaarthakal Ithuvare',
#     'country of Vaarthakal Ithuvare?'],
#    'responses': ['India'],
#    'context': ['']},
#   {'tag': 'Vaarthakal Ithuvare language',
#    'patterns': ['language of Vaarthakal Ithuvare',
#     'What is the language of Vaarthakal Ithuvare',
#     'language of Vaarthakal Ithuvare?'],
#    'responses': ['Malayalam'],
#    'context': ['']},
#   {'tag': 'Vaarthakal Ithuvare director',
#    'patterns': ['director of Vaarthakal Ithuvare',
#     'Who is the director of Vaarthakal Ithuvare',
#     'director of Vaarthakal Ithuvare?'],
#    'responses': ['Manoj Nair'],
#    'context': ['']},
#   {'tag': 'Vaarthakal Ithuvare writer',
#    'patterns': ['writer of Vaarthakal Ithuvare',
#     'Who is the writer of Vaarthakal Ithuvare',
#     'writer of Vaarthakal Ithuvare?'],
#    'responses': ['Manoj Nair'],
#    'context': ['']},
#   {'tag': 'Vaarthakal Ithuvare producer',
#    'patterns': ['producer of Vaarthakal Ithuvare',
#     'Who is the producer of Vaarthakal Ithuvare',
#     'producer of Vaarthakal Ithuvare?'],
#    'responses': ['Lawson Entertainment'],
#    'context': ['']},
#   {'tag': 'Vaarthakal Ithuvare actors',
#    'patterns': ['actors of Vaarthakal Ithuvare',
#     'Who are the principle actors of Vaarthakal Ithuvare',
#     'Who are the actors of Vaarthakal Ithuvare',
#     'Who are the main actors of Vaarthakal Ithuvare',
#     'actors of Vaarthakal Ithuvare?'],
#    'responses': ['Siju Wilson, Nandu, Vinay Forrt, Mammukoya, Alencier Ley Lopez, Nedumudi Venu, Indrans, Saiju Kurup, Sunil Sukhada, Pauly Valsan, Aurora Adya, P. Balachandran, Abhirami Bhargavan, Shivaji Guruvayoor, Sudheer Karamana'],
#    'context': ['']},
#   {'tag': 'Vaarthakal Ithuvare description',
#    'patterns': ['description of Vaarthakal Ithuvare',
#     'What is the description of Vaarthakal Ithuvare',
#     'description of Vaarthakal Ithuvare?'],
#    'responses': ['Ittan Pillai, the police station head finds himself encapsulated in a case of theft which leads him and the others through a series of chained events throwing the case into a spiral.'],
#    'context': ['']},
#   {'tag': 'Vaarthakal Ithuvare average of votes',
#    'patterns': ['average of votes of Vaarthakal Ithuvare',
#     'What is the average of votes of Vaarthakal Ithuvare',
#     'average of votes of Vaarthakal Ithuvare?'],
#    'responses': ['9.7'],
#    'context': ['']},
#   {'tag': 'Vaarthakal Ithuvare number of votes',
#    'patterns': ['number of votes of Vaarthakal Ithuvare',
#     'What is the number of votes of Vaarthakal Ithuvare',
#     'number of votes of Vaarthakal Ithuvare?'],
#    'responses': ['473'],
#    'context': ['']},
#   {'tag': 'Vaarthakal Ithuvare budget',
#    'patterns': ['budget of Vaarthakal Ithuvare',
#     'What is the budget of Vaarthakal Ithuvare',
#     'budget of Vaarthakal Ithuvare?'],
#    'responses': ['nan'],
#    'context': ['']},
#   {'tag': 'Vaarthakal Ithuvare number of reviews from users',
#    'patterns': ['number of reviews from users of Vaarthakal Ithuvare',
#     'What is the number of reviews from users of Vaarthakal Ithuvare',
#     'number of reviews from users of Vaarthakal Ithuvare?'],
#    'responses': ['20.0'],
#    'context': ['']},
#   {'tag': 'Vaarthakal Ithuvare number of reviews from critics',
#    'patterns': ['number of reviews from critics of Vaarthakal Ithuvare',
#     'What is the number of reviews from critics of Vaarthakal Ithuvare',
#     'number of reviews from critics of Vaarthakal Ithuvare?'],
#    'responses': ['nan'],
#    'context': ['']},
#   {'tag': 'Isha title',
#    'patterns': ['title of Isha',
#     'What is the title of Isha',
#     'title of Isha?'],
#    'responses': ['Isha'],
#    'context': ['']},
#   {'tag': 'Isha original title',
#    'patterns': ['original title of Isha',
#     'What is the original title of Isha',
#     'original title of Isha?'],
#    'responses': ['Isha'],
#    'context': ['']},
#   {'tag': 'Isha year',
#    'patterns': ['year of Isha', 'What is the year of Isha', 'year of Isha?'],
#    'responses': ['2020'],
#    'context': ['']},
#   {'tag': 'Isha date',
#    'patterns': ['date of Isha', 'What is the date of Isha', 'date of Isha?'],
#    'responses': ['2020-02-28'],
#    'context': ['']},
#   {'tag': 'Isha genre',
#    'patterns': ['genre of Isha',
#     'What is the genre of Isha',
#     'genre of Isha?'],
#    'responses': ['Drama, Horror'],
#    'context': ['']},
#   {'tag': 'Isha duration',
#    'patterns': ['duration of Isha',
#     'What is the duration of Isha',
#     'duration of Isha?'],
#    'responses': ['118'],
#    'context': ['']},
#   {'tag': 'Isha country',
#    'patterns': ['country of Isha',
#     'What is the country of Isha',
#     'country of Isha?'],
#    'responses': ['India'],
#    'context': ['']},
#   {'tag': 'Isha language',
#    'patterns': ['language of Isha',
#     'What is the language of Isha',
#     'language of Isha?'],
#    'responses': ['Malayalam'],
#    'context': ['']},
#   {'tag': 'Isha director',
#    'patterns': ['director of Isha',
#     'Who is the director of Isha',
#     'director of Isha?'],
#    'responses': ['Jose Thomas'],
#    'context': ['']},
#   {'tag': 'Isha writer',
#    'patterns': ['writer of Isha',
#     'Who is the writer of Isha',
#     'writer of Isha?'],
#    'responses': ['Jose Thomas'],
#    'context': ['']},
#   {'tag': 'Isha producer',
#    'patterns': ['producer of Isha',
#     'Who is the producer of Isha',
#     'producer of Isha?'],
#    'responses': ['Visual Dreams Production'],
#    'context': ['']},
#   {'tag': 'Isha actors',
#    'patterns': ['actors of Isha',
#     'Who are the principle actors of Isha',
#     'Who are the actors of Isha',
#     'Who are the main actors of Isha',
#     'actors of Isha?'],
#    'responses': ['Kishore Satya, Abhishek Vinod'],
#    'context': ['']},
#   {'tag': 'Isha description',
#    'patterns': ['description of Isha',
#     'What is the description of Isha',
#     'description of Isha?'],
#    'responses': ['nan'],
#    'context': ['']},
#   {'tag': 'Isha average of votes',
#    'patterns': ['average of votes of Isha',
#     'What is the average of votes of Isha',
#     'average of votes of Isha?'],
#    'responses': ['9.5'],
#    'context': ['']},
#   {'tag': 'Isha number of votes',
#    'patterns': ['number of votes of Isha',
#     'What is the number of votes of Isha',
#     'number of votes of Isha?'],
#    'responses': ['392'],
#    'context': ['']},
#   {'tag': 'Isha budget',
#    'patterns': ['budget of Isha',
#     'What is the budget of Isha',
#     'budget of Isha?'],
#    'responses': ['INR 22000000'],
#    'context': ['']},
#   {'tag': 'Isha number of reviews from users',
#    'patterns': ['number of reviews from users of Isha',
#     'What is the number of reviews from users of Isha',
#     'number of reviews from users of Isha?'],
#    'responses': ['12.0'],
#    'context': ['']},
#   {'tag': 'Isha number of reviews from critics',
#    'patterns': ['number of reviews from critics of Isha',
#     'What is the number of reviews from critics of Isha',
#     'number of reviews from critics of Isha?'],
#    'responses': ['nan'],
#    'context': ['']},
#   {'tag': 'The Moving on Phase title',
#    'patterns': ['title of The Moving on Phase',
#     'What is the title of The Moving on Phase',
#     'title of The Moving on Phase?'],
#    'responses': ['The Moving on Phase'],
#    'context': ['']},
#   {'tag': 'The Moving on Phase original title',
#    'patterns': ['original title of The Moving on Phase',
#     'What is the original title of The Moving on Phase',
#     'original title of The Moving on Phase?'],
#    'responses': ['The Moving on Phase'],
#    'context': ['']},
#   {'tag': 'The Moving on Phase year',
#    'patterns': ['year of The Moving on Phase',
#     'What is the year of The Moving on Phase',
#     'year of The Moving on Phase?'],
#    'responses': ['2020'],
#    'context': ['']},
#   {'tag': 'The Moving on Phase date',
#    'patterns': ['date of The Moving on Phase',
#     'What is the date of The Moving on Phase',
#     'date of The Moving on Phase?'],
#    'responses': ['2020-05-11'],
#    'context': ['']},
#   {'tag': 'The Moving on Phase genre',
#    'patterns': ['genre of The Moving on Phase',
#     'What is the genre of The Moving on Phase',
#     'genre of The Moving on Phase?'],
#    'responses': ['Comedy'],
#    'context': ['']},
#   {'tag': 'The Moving on Phase duration',
#    'patterns': ['duration of The Moving on Phase',
#     'What is the duration of The Moving on Phase',
#     'duration of The Moving on Phase?'],
#    'responses': ['85'],
#    'context': ['']},
#   {'tag': 'The Moving on Phase country',
#    'patterns': ['country of The Moving on Phase',
#     'What is the country of The Moving on Phase',
#     'country of The Moving on Phase?'],
#    'responses': ['USA'],
#    'context': ['']},
#   {'tag': 'The Moving on Phase language',
#    'patterns': ['language of The Moving on Phase',
#     'What is the language of The Moving on Phase',
#     'language of The Moving on Phase?'],
#    'responses': ['English'],
#    'context': ['']},
#   {'tag': 'The Moving on Phase director',
#    'patterns': ['director of The Moving on Phase',
#     'Who is the director of The Moving on Phase',
#     'director of The Moving on Phase?'],
#    'responses': ['Don Tjernagel'],
#    'context': ['']},
#   {'tag': 'The Moving on Phase writer',
#    'patterns': ['writer of The Moving on Phase',
#     'Who is the writer of The Moving on Phase',
#     'writer of The Moving on Phase?'],
#    'responses': ['Don Tjernagel'],
#    'context': ['']},
#   {'tag': 'The Moving on Phase producer',
#    'patterns': ['producer of The Moving on Phase',
#     'Who is the producer of The Moving on Phase',
#     'producer of The Moving on Phase?'],
#    'responses': ['nan'],
#    'context': ['']},
#   {'tag': 'The Moving on Phase actors',
#    'patterns': ['actors of The Moving on Phase',
#     'Who are the principle actors of The Moving on Phase',
#     'Who are the actors of The Moving on Phase',
#     'Who are the main actors of The Moving on Phase',
#     'actors of The Moving on Phase?'],
#    'responses': ['Matt Anderson, Clint Boevers, Jillian Brown, Cody Croskrey, Jamie Doroslovac, Piper Freestone, Skott Green, Andrew Hunt, Matt Lee Ingebritson, Lily Jensen, Corey Kerr, Zach Litzkow, Michaela Merchant, Jordan Rottinghaus, Dylan Simmons'],
#    'context': ['']},
#   {'tag': 'The Moving on Phase description',
#    'patterns': ['description of The Moving on Phase',
#     'What is the description of The Moving on Phase',
#     'description of The Moving on Phase?'],
#    'responses': ['Piper is a young adult female that is forced into a life change after long time boyfriend breaks it off and evicts her from their home.'],
#    'context': ['']},
#   {'tag': 'The Moving on Phase average of votes',
#    'patterns': ['average of votes of The Moving on Phase',
#     'What is the average of votes of The Moving on Phase',
#     'average of votes of The Moving on Phase?'],
#    'responses': ['9.5'],
#    'context': ['']},
#   {'tag': 'The Moving on Phase number of votes',
#    'patterns': ['number of votes of The Moving on Phase',
#     'What is the number of votes of The Moving on Phase',
#     'number of votes of The Moving on Phase?'],
#    'responses': ['172'],
#    'context': ['']},
#   {'tag': 'The Moving on Phase budget',
#    'patterns': ['budget of The Moving on Phase',
#     'What is the budget of The Moving on Phase',
#     'budget of The Moving on Phase?'],
#    'responses': ['nan'],
#    'context': ['']},
#   {'tag': 'The Moving on Phase number of reviews from users',
#    'patterns': ['number of reviews from users of The Moving on Phase',
#     'What is the number of reviews from users of The Moving on Phase',
#     'number of reviews from users of The Moving on Phase?'],
#    'responses': ['nan'],
#    'context': ['']},
#   {'tag': 'The Moving on Phase number of reviews from critics',
#    'patterns': ['number of reviews from critics of The Moving on Phase',
#     'What is the number of reviews from critics of The Moving on Phase',
#     'number of reviews from critics of The Moving on Phase?'],
#    'responses': ['nan'],
#    'context': ['']},
#   {'tag': 'Jibon Theke Neya title',
#    'patterns': ['title of Jibon Theke Neya',
#     'What is the title of Jibon Theke Neya',
#     'title of Jibon Theke Neya?'],
#    'responses': ['Jibon Theke Neya'],
#    'context': ['']},
#   {'tag': 'Jibon Theke Neya original title',
#    'patterns': ['original title of Jibon Theke Neya',
#     'What is the original title of Jibon Theke Neya',
#     'original title of Jibon Theke Neya?'],
#    'responses': ['Jibon Theke Neya'],
#    'context': ['']},
#   {'tag': 'Jibon Theke Neya year',
#    'patterns': ['year of Jibon Theke Neya',
#     'What is the year of Jibon Theke Neya',
#     'year of Jibon Theke Neya?'],
#    'responses': ['1970'],
#    'context': ['']},
#   {'tag': 'Jibon Theke Neya date',
#    'patterns': ['date of Jibon Theke Neya',
#     'What is the date of Jibon Theke Neya',
#     'date of Jibon Theke Neya?'],
#    'responses': ['1970-04-10'],
#    'context': ['']},
#   {'tag': 'Jibon Theke Neya genre',
#    'patterns': ['genre of Jibon Theke Neya',
#     'What is the genre of Jibon Theke Neya',
#     'genre of Jibon Theke Neya?'],
#    'responses': ['Drama, Family, War'],
#    'context': ['']},
#   {'tag': 'Jibon Theke Neya duration',
#    'patterns': ['duration of Jibon Theke Neya',
#     'What is the duration of Jibon Theke Neya',
#     'duration of Jibon Theke Neya?'],
#    'responses': ['150'],
#    'context': ['']},
#   {'tag': 'Jibon Theke Neya country',
#    'patterns': ['country of Jibon Theke Neya',
#     'What is the country of Jibon Theke Neya',
#     'country of Jibon Theke Neya?'],
#    'responses': ['Bangladesh'],
#    'context': ['']},
#   {'tag': 'Jibon Theke Neya language',
#    'patterns': ['language of Jibon Theke Neya',
#     'What is the language of Jibon Theke Neya',
#     'language of Jibon Theke Neya?'],
#    'responses': ['Bengali'],
#    'context': ['']},
#   {'tag': 'Jibon Theke Neya director',
#    'patterns': ['director of Jibon Theke Neya',
#     'Who is the director of Jibon Theke Neya',
#     'director of Jibon Theke Neya?'],
#    'responses': ['Zahir Raihan'],
#    'context': ['']},
#   {'tag': 'Jibon Theke Neya writer',
#    'patterns': ['writer of Jibon Theke Neya',
#     'Who is the writer of Jibon Theke Neya',
#     'writer of Jibon Theke Neya?'],
#    'responses': ['Zahir Raihan, Amjad Hossain'],
#    'context': ['']},
#   {'tag': 'Jibon Theke Neya producer',
#    'patterns': ['producer of Jibon Theke Neya',
#     'Who is the producer of Jibon Theke Neya',
#     'producer of Jibon Theke Neya?'],
#    'responses': ['Cine Workshop'],
#    'context': ['']},
#   {'tag': 'Jibon Theke Neya actors',
#    'patterns': ['actors of Jibon Theke Neya',
#     'Who are the principle actors of Jibon Theke Neya',
#     'Who are the actors of Jibon Theke Neya',
# ...
#    'context': ['']},
#   {'tag': 'National Theatre Live: Angels in America Part Two - Perestroika duration',
#    'patterns': ['duration of National Theatre Live: Angels in America Part Two - Perestroika',
#     'What is the duration of National Theatre Live: Angels in America Part Two - Perestroika',
#     'duration of National Theatre Live: Angels in America Part Two - Perestroika?'],
#    'responses': ['220'],
#    'context': ['']},
#   {'tag': 'National Theatre Live: Angels in America Part Two - Perestroika country',
#    'patterns': ['country of National Theatre Live: Angels in America Part Two - Perestroika',
#     'What is the country of National Theatre Live: Angels in America Part Two - Perestroika',
#     'country of National Theatre Live: Angels in America Part Two - Perestroika?'],
#    'responses': ['UK'],
#    'context': ['']},
#   {'tag': 'National Theatre Live: Angels in America Part Two - Perestroika language',
#    'patterns': ['language of National Theatre Live: Angels in America Part Two - Perestroika',
#     'What is the language of National Theatre Live: Angels in America Part Two - Perestroika',
#     'language of National Theatre Live: Angels in America Part Two - Perestroika?'],
#    'responses': ['English'],
#    'context': ['']},
#   {'tag': 'National Theatre Live: Angels in America Part Two - Perestroika director',
#    'patterns': ['director of National Theatre Live: Angels in America Part Two - Perestroika',
#     'Who is the director of National Theatre Live: Angels in America Part Two - Perestroika',
#     'director of National Theatre Live: Angels in America Part Two - Perestroika?'],
#    'responses': ['Marianne Elliott'],
#    'context': ['']},
#   {'tag': 'National Theatre Live: Angels in America Part Two - Perestroika writer',
#    'patterns': ['writer of National Theatre Live: Angels in America Part Two - Perestroika',
#     'Who is the writer of National Theatre Live: Angels in America Part Two - Perestroika',
#     'writer of National Theatre Live: Angels in America Part Two - Perestroika?'],
#    'responses': ['Tony Kushner'],
#    'context': ['']},
#   {'tag': 'National Theatre Live: Angels in America Part Two - Perestroika producer',
#    'patterns': ['producer of National Theatre Live: Angels in America Part Two - Perestroika',
#     'Who is the producer of National Theatre Live: Angels in America Part Two - Perestroika',
#     'producer of National Theatre Live: Angels in America Part Two - Perestroika?'],
#    'responses': ['National Theatre Live'],
#    'context': ['']},
#   {'tag': 'National Theatre Live: Angels in America Part Two - Perestroika actors',
#    'patterns': ['actors of National Theatre Live: Angels in America Part Two - Perestroika',
#     'Who are the principle actors of National Theatre Live: Angels in America Part Two - Perestroika',
#     'Who are the actors of National Theatre Live: Angels in America Part Two - Perestroika',
#     'Who are the main actors of National Theatre Live: Angels in America Part Two - Perestroika',
#     'actors of National Theatre Live: Angels in America Part Two - Perestroika?'],
#    'responses': ['Andrew Garfield, Russell Tovey, Nathan Lane, Denise Gough, Nathan Stewart-Jarrett, James McArdle, Amanda Lawrence, Susan Brown, Edith Bowman, Stuart Angell'],
#    'context': ['']},
#   {'tag': 'National Theatre Live: Angels in America Part Two - Perestroika description',
#    'patterns': ['description of National Theatre Live: Angels in America Part Two - Perestroika',
#     'What is the description of National Theatre Live: Angels in America Part Two - Perestroika',
#     'description of National Theatre Live: Angels in America Part Two - Perestroika?'],
#    'responses': ['America in the mid-1980s. In the midst of the AIDS crisis and a conservative Reagan administration, New Yorkers grapple with life and death, love and sex, heaven and hell.'],
#    'context': ['']},
#   {'tag': 'National Theatre Live: Angels in America Part Two - Perestroika average of votes',
#    'patterns': ['average of votes of National Theatre Live: Angels in America Part Two - Perestroika',
#     'What is the average of votes of National Theatre Live: Angels in America Part Two - Perestroika',
#     'average of votes of National Theatre Live: Angels in America Part Two - Perestroika?'],
#    'responses': ['9.0'],
#    'context': ['']},
#   {'tag': 'National Theatre Live: Angels in America Part Two - Perestroika number of votes',
#    'patterns': ['number of votes of National Theatre Live: Angels in America Part Two - Perestroika',
#     'What is the number of votes of National Theatre Live: Angels in America Part Two - Perestroika',
#     'number of votes of National Theatre Live: Angels in America Part Two - Perestroika?'],
#    'responses': ['337'],
#    'context': ['']},
#   {'tag': 'National Theatre Live: Angels in America Part Two - Perestroika budget',
#    'patterns': ['budget of National Theatre Live: Angels in America Part Two - Perestroika',
#     'What is the budget of National Theatre Live: Angels in America Part Two - Perestroika',
#     'budget of National Theatre Live: Angels in America Part Two - Perestroika?'],
#    'responses': ['nan'],
#    'context': ['']},
#   {'tag': 'National Theatre Live: Angels in America Part Two - Perestroika number of reviews from users',
#    'patterns': ['number of reviews from users of National Theatre Live: Angels in America Part Two - Perestroika',
#     'What is the number of reviews from users of National Theatre Live: Angels in America Part Two - Perestroika',
#     'number of reviews from users of National Theatre Live: Angels in America Part Two - Perestroika?'],
#    'responses': ['3.0'],
#    'context': ['']},
#   {'tag': 'National Theatre Live: Angels in America Part Two - Perestroika number of reviews from critics',
#    'patterns': ['number of reviews from critics of National Theatre Live: Angels in America Part Two - Perestroika',
#     'What is the number of reviews from critics of National Theatre Live: Angels in America Part Two - Perestroika',
#     'number of reviews from critics of National Theatre Live: Angels in America Part Two - Perestroika?'],
#    'responses': ['3.0'],
#    'context': ['']},
#   {'tag': 'Breakout title',
#    'patterns': ['title of Breakout',
#     'What is the title of Breakout',
#     'title of Breakout?'],
#    'responses': ['Breakout'],
#    'context': ['']},
#   {'tag': 'Breakout original title',
#    'patterns': ['original title of Breakout',
#     'What is the original title of Breakout',
#     'original title of Breakout?'],
#    'responses': ['Breakout'],
#    'context': ['']},
#   {'tag': 'Breakout year',
#    'patterns': ['year of Breakout',
#     'What is the year of Breakout',
#     'year of Breakout?'],
#    'responses': ['2019'],
#    'context': ['']},
#   {'tag': 'Breakout date',
#    'patterns': ['date of Breakout',
#     'What is the date of Breakout',
#     'date of Breakout?'],
#    'responses': ['2019-11-15'],
#    'context': ['']},
#   {'tag': 'Breakout genre',
#    'patterns': ['genre of Breakout',
#     'What is the genre of Breakout',
#     'genre of Breakout?'],
#    'responses': ['Adventure, Comedy, Drama'],
#    'context': ['']},
#   {'tag': 'Breakout duration',
#    'patterns': ['duration of Breakout',
#     'What is the duration of Breakout',
#     'duration of Breakout?'],
#    'responses': ['58'],
#    'context': ['']},
#   {'tag': 'Breakout country',
#    'patterns': ['country of Breakout',
#     'What is the country of Breakout',
#     'country of Breakout?'],
#    'responses': ['UK'],
#    'context': ['']},
#   {'tag': 'Breakout language',
#    'patterns': ['language of Breakout',
#     'What is the language of Breakout',
#     'language of Breakout?'],
#    'responses': ['English'],
#    'context': ['']},
#   {'tag': 'Breakout director',
#    'patterns': ['director of Breakout',
#     'Who is the director of Breakout',
#     'director of Breakout?'],
#    'responses': ['nan'],
#    'context': ['']},
#   {'tag': 'Breakout writer',
#    'patterns': ['writer of Breakout',
#     'Who is the writer of Breakout',
#     'writer of Breakout?'],
#    'responses': ['Dan'],
#    'context': ['']},
#   {'tag': 'Breakout producer',
#    'patterns': ['producer of Breakout',
#     'Who is the producer of Breakout',
#     'producer of Breakout?'],
#    'responses': ['Tycer Studios'],
#    'context': ['']},
#   {'tag': 'Breakout actors',
#    'patterns': ['actors of Breakout',
#     'Who are the principle actors of Breakout',
#     'Who are the actors of Breakout',
#     'Who are the main actors of Breakout',
#     'actors of Breakout?'],
#    'responses': ['Arran, Dan, Leonie, Carl'],
#    'context': ['']},
#   {'tag': 'Breakout description',
#    'patterns': ['description of Breakout',
#     'What is the description of Breakout',
#     'description of Breakout?'],
#    'responses': ["Jerry with Freddy and Chica is trapped within the FNAF pizzeria. After Jerry finding out who his dad really was.. he's determined to save him, however not before the FNAF Security Service ..."],
#    'context': ['']},
#   {'tag': 'Breakout average of votes',
#    'patterns': ['average of votes of Breakout',
#     'What is the average of votes of Breakout',
#     'average of votes of Breakout?'],
#    'responses': ['9.0'],
#    'context': ['']},
#   {'tag': 'Breakout number of votes',
#    'patterns': ['number of votes of Breakout',
#     'What is the number of votes of Breakout',
#     'number of votes of Breakout?'],
#    'responses': ['165'],
#    'context': ['']},
#   {'tag': 'Breakout budget',
#    'patterns': ['budget of Breakout',
#     'What is the budget of Breakout',
#     'budget of Breakout?'],
#    'responses': ['GBP 1000'],
#    'context': ['']},
#   {'tag': 'Breakout number of reviews from users',
#    'patterns': ['number of reviews from users of Breakout',
#     'What is the number of reviews from users of Breakout',
#     'number of reviews from users of Breakout?'],
#    'responses': ['nan'],
#    'context': ['']},
#   {'tag': 'Breakout number of reviews from critics',
#    'patterns': ['number of reviews from critics of Breakout',
#     'What is the number of reviews from critics of Breakout',
#     'number of reviews from critics of Breakout?'],
#    'responses': ['nan'],
#    'context': ['']},
#   {'tag': 'Precure Miracle Universe Movie title',
#    'patterns': ['title of Precure Miracle Universe Movie',
#     'What is the title of Precure Miracle Universe Movie',
#     'title of Precure Miracle Universe Movie?'],
#    'responses': ['Precure Miracle Universe Movie'],
#    'context': ['']},
#   {'tag': 'Precure Miracle Universe Movie original title',
#    'patterns': ['original title of Precure Miracle Universe Movie',
#     'What is the original title of Precure Miracle Universe Movie',
#     'original title of Precure Miracle Universe Movie?'],
#    'responses': ['Precure Miracle Universe Movie'],
#    'context': ['']},
#   {'tag': 'Precure Miracle Universe Movie year',
#    'patterns': ['year of Precure Miracle Universe Movie',
#     'What is the year of Precure Miracle Universe Movie',
#     'year of Precure Miracle Universe Movie?'],
#    'responses': ['2019'],
#    'context': ['']},
#   {'tag': 'Precure Miracle Universe Movie date',
#    'patterns': ['date of Precure Miracle Universe Movie',
#     'What is the date of Precure Miracle Universe Movie',
#     'date of Precure Miracle Universe Movie?'],
#    'responses': ['2019-03-16'],
#    'context': ['']},
#   {'tag': 'Precure Miracle Universe Movie genre',
#    'patterns': ['genre of Precure Miracle Universe Movie',
#     'What is the genre of Precure Miracle Universe Movie',
#     'genre of Precure Miracle Universe Movie?'],
#    'responses': ['Animation, Adventure, Family'],
#    'context': ['']},
#   {'tag': 'Precure Miracle Universe Movie duration',
#    'patterns': ['duration of Precure Miracle Universe Movie',
#     'What is the duration of Precure Miracle Universe Movie',
#     'duration of Precure Miracle Universe Movie?'],
#    'responses': ['70'],
#    'context': ['']},
#   {'tag': 'Precure Miracle Universe Movie country',
#    'patterns': ['country of Precure Miracle Universe Movie',
#     'What is the country of Precure Miracle Universe Movie',
#     'country of Precure Miracle Universe Movie?'],
#    'responses': ['Japan'],
#    'context': ['']},
#   {'tag': 'Precure Miracle Universe Movie language',
#    'patterns': ['language of Precure Miracle Universe Movie',
#     'What is the language of Precure Miracle Universe Movie',
#     'language of Precure Miracle Universe Movie?'],
#    'responses': ['Japanese'],
#    'context': ['']},
#   {'tag': 'Precure Miracle Universe Movie director',
#    'patterns': ['director of Precure Miracle Universe Movie',
#     'Who is the director of Precure Miracle Universe Movie',
#     'director of Precure Miracle Universe Movie?'],
#    'responses': ['Yukio Kaizawa'],
#    'context': ['']},
#   {'tag': 'Precure Miracle Universe Movie writer',
#    'patterns': ['writer of Precure Miracle Universe Movie',
#     'Who is the writer of Precure Miracle Universe Movie',
#     'writer of Precure Miracle Universe Movie?'],
#    'responses': ['nan'],
#    'context': ['']},
#   {'tag': 'Precure Miracle Universe Movie producer',
#    'patterns': ['producer of Precure Miracle Universe Movie',
#     'Who is the producer of Precure Miracle Universe Movie',
#     'producer of Precure Miracle Universe Movie?'],
#    'responses': ['Toei Animation'],
#    'context': ['']},
#   {'tag': 'Precure Miracle Universe Movie actors',
#    'patterns': ['actors of Precure Miracle Universe Movie',
#     'Who are the principle actors of Precure Miracle Universe Movie',
#     'Who are the actors of Precure Miracle Universe Movie',
#     'Who are the main actors of Precure Miracle Universe Movie',
#     'actors of Precure Miracle Universe Movie?'],
#    'responses': ['nan'],
#    'context': ['']},
#   {'tag': 'Precure Miracle Universe Movie description',
#    'patterns': ['description of Precure Miracle Universe Movie',
#     'What is the description of Precure Miracle Universe Movie',
#     'description of Precure Miracle Universe Movie?'],
#    'responses': ['nan'],
#    'context': ['']},
#   {'tag': 'Precure Miracle Universe Movie average of votes',
#    'patterns': ['average of votes of Precure Miracle Universe Movie',
#     'What is the average of votes of Precure Miracle Universe Movie',
#     'average of votes of Precure Miracle Universe Movie?'],
#    'responses': ['9.0'],
#    'context': ['']},
#   {'tag': 'Precure Miracle Universe Movie number of votes',
#    'patterns': ['number of votes of Precure Miracle Universe Movie',
#     'What is the number of votes of Precure Miracle Universe Movie',
#     'number of votes of Precure Miracle Universe Movie?'],
#    'responses': ['110'],
#    'context': ['']},
#   {'tag': 'Precure Miracle Universe Movie budget',
#    'patterns': ['budget of Precure Miracle Universe Movie',
#     'What is the budget of Precure Miracle Universe Movie',
#     'budget of Precure Miracle Universe Movie?'],
#    'responses': ['nan'],
#    'context': ['']},
#   {'tag': 'Precure Miracle Universe Movie number of reviews from users',
#    'patterns': ['number of reviews from users of Precure Miracle Universe Movie',
#     'What is the number of reviews from users of Precure Miracle Universe Movie',
#     'number of reviews from users of Precure Miracle Universe Movie?'],
#    'responses': ['nan'],
#    'context': ['']},
#   {'tag': 'Precure Miracle Universe Movie number of reviews from critics',
#    'patterns': ['number of reviews from critics of Precure Miracle Universe Movie',
#     'What is the number of reviews from critics of Precure Miracle Universe Movie',
#     'number of reviews from critics of Precure Miracle Universe Movie?'],
#    'responses': ['nan'],
#    'context': ['']},
#   {'tag': 'Pulp Fiction title',
#    'patterns': ['title of Pulp Fiction',
#     'What is the title of Pulp Fiction',
#     'title of Pulp Fiction?'],
#    'responses': ['Pulp Fiction'],
#    'context': ['']},
#   {'tag': 'Pulp Fiction original title',
#    'patterns': ['original title of Pulp Fiction',
#     'What is the original title of Pulp Fiction',
#     'original title of Pulp Fiction?'],
#    'responses': ['Pulp Fiction'],
#    'context': ['']},
#   {'tag': 'Pulp Fiction year',
#    'patterns': ['year of Pulp Fiction',
#     'What is the year of Pulp Fiction',
#     'year of Pulp Fiction?'],
#    'responses': ['1994'],
#    'context': ['']},
#   ...]}

# %%
import json
with open("movies_imdb.json", "w") as write_file:
    json.dump(mov, write_file)
